# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import ascii, votable

# %%
#f = ascii.read('Sgr_long.csv')
f2 = votable.parse('Galactic_Polar_5million.votableB1.xml')
# Out:
# WARNING: W50: Galactic_Polar_5million.votableB1.xml:14:2: W50: Invalid unit string 'Magnitude[mag]' [astropy.io.votable.tree]
# WARNING: W50: Galactic_Polar_5million.votableB1.xml:15:2: W50: Invalid unit string 'Angle[deg]' [astropy.io.votable.tree]
# WARNING: W50: Galactic_Polar_5million.votableB1.xml:16:2: W50: Invalid unit string 'Angle[deg]' [astropy.io.votable.tree]

# %%
table = f2.get_first_table()

# %%
selected = (table.array['l']>40) * (table.array['l']<44)  *  (table.array['b']>78.2) * (table.array['b']<79)

# %%
H.sum()
# Out:
# 22845.0

# %%
H, xedges, yedges = np.histogram2d(table.array['l'][selected], table.array['b'][selected], bins=(300, 300))
H = H.T
X, Y = np.meshgrid(xedges, yedges)
plt.figure(figsize=(12,12))
plt.pcolormesh(X, Y, H)
#plt.imshow(H)
plt.show()

# %%
1!=2
# Out:
# True
