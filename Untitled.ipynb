# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import ascii, votable
from astropy.table import Table, vstack, hstack

# %%
666301984848583296
6384828258303948544
754884761910483200
6079072835044321280

# %%
dir_rrlyrae = '/datascope/menard/DATA/Gaia/gdr2/vari_rrlyrae/'

# %% [markdown]
# ## packing VariRrlyrae_i.csv into a list

# %%
rrlyrae_list = []
for i in range(64):
    rrlyrae.append( Table.read('/datascope/menard/DATA/Gaia/gdr2/vari_rrlyrae/csv/VariRrlyrae_'+str(i)+'.csv',format='ascii') )
print(i)

# %%
l = 0
for i in range(64):
    l += len(Table.read('/datascope/menard/DATA/Gaia/gdr2/vari_rrlyrae/csv/VariRrlyrae_'+str(i)+'.csv',format='ascii'))
print(l)
# Out:
# 140784

# %% [markdown]
# ## packing VariRrlyrae_i.csv into one table

# %%
rrlyrae_combined = rrlyrae_list[0]
for i in range(1,64):
    rrlyrae_combined = vstack([rrlyrae_combined,rrlyrae_list[i]])
print(i)

# %%
len(rrlyrae_combined)
# Out:
# 140784

# %% [markdown]
# ## write combined table

# %%
Table.write(rrlyrae_combined,'/datascope/menard/DATA/Gaia/gdr2/vari_rrlyrae/VariRrlyrae_combined.csv',format='csv')
# Out:
# WARNING: AstropyDeprecationWarning: /datascope/menard/DATA/Gaia/gdr2/vari_rrlyrae/VariRrlyrae_combined.csv already exists. Automatically overwriting ASCII files is deprecated. Use the argument 'overwrite=True' in the future. [astropy.io.ascii.ui]

# %% [markdown]
# ## Reopen it

# %%
VariRrlyrae_combined = Table.read('/datascope/menard/DATA/Gaia/gdr2/vari_rrlyrae/VariRrlyrae_combined.csv',format='csv')

# %%
VariRrlyrae_combined['source_id']
# Out:
# <MaskedColumn name='source_id' dtype='int64' length=140784>
# 4064863289398606208
# 4064863843377219712
# 4064868031049398272
# 4064878171393367040
# 4064901707769275392
# 4064911740815901440
# 4064914210604461568
# 4065112985826002048
# 4065169228472839296
# 4065224032144111744
# 4065236990111993728
# 4065287528936886144
#                 ...
# 6222953311740065920
# 6223152941819919872
# 6224116075351318656
# 6225507030575124736
# 6225547437627310592
# 6230290142377101824
# 6233118361163604096
# 6243953777675294848
# 6250447905661241088
# 6256366641177898496
# 6256568508937271808
# 6258131808313752192

# %%
plt.hist(VariRrlyrae_combined['source_id'],10)
# Out:
# (array([ 2737.,  3980.,  9502.,  4484.,  2863., 16922., 45193., 14220.,
#         26140., 14743.]),
#  array([2.88243845e+14, 6.91985827e+17, 1.38368341e+18, 2.07538099e+18,
#         2.76707858e+18, 3.45877616e+18, 4.15047375e+18, 4.84217133e+18,
#         5.53386891e+18, 6.22556650e+18, 6.91726408e+18]),
#  <a list of 10 Patch objects>)

# %%
from astropy.io import ascii, votable
f2 = votable.parse(dir_rrlyrae+'main_plus_rrlyrae.vot')
table = f2.get_first_table()
# Out:
# WARNING: W27: /datascope/menard/DATA/Gaia/gdr2/vari_rrlyrae/main_plus_rrlyrae.vot:3:0: W27: COOSYS deprecated in VOTable 1.2 [astropy.io.votable.tree]
# WARNING: W35: /datascope/menard/DATA/Gaia/gdr2/vari_rrlyrae/main_plus_rrlyrae.vot:5:0: W35: 'value' attribute required for INFO elements [astropy.io.votable.tree]
# WARNING: W35: /datascope/menard/DATA/Gaia/gdr2/vari_rrlyrae/main_plus_rrlyrae.vot:8:0: W35: 'value' attribute required for INFO elements [astropy.io.votable.tree]
# WARNING: W35: /datascope/menard/DATA/Gaia/gdr2/vari_rrlyrae/main_plus_rrlyrae.vot:9:0: W35: 'value' attribute required for INFO elements [astropy.io.votable.tree]
# WARNING: W35: /datascope/menard/DATA/Gaia/gdr2/vari_rrlyrae/main_plus_rrlyrae.vot:10:0: W35: 'value' attribute required for INFO elements [astropy.io.votable.tree]
# WARNING: W35: /datascope/menard/DATA/Gaia/gdr2/vari_rrlyrae/main_plus_rrlyrae.vot:12:0: W35: 'value' attribute required for INFO elements [astropy.io.votable.tree]
# ...

# %%
len(table.array)
# Out:
# 140784

# %%
bp_rp = table.array['phot_bp_mean_mag']-table.array['phot_rp_mean_mag']
g = table.array['phot_g_mean_mag']
l = table.array['l']
b = table.array['b']

# %%
plt.figure(figsize=(6,6))

x = table.array['l']
y = table.array['b']
z= table.array['phot_g_mean_mag']
selected = np.where((np.abs(b-8.6)<2) * (np.abs(l-275.4)<5))[0]

plt.scatter(x[selected],y[selected],1,c=z[selected],alpha=0.5)
#plt.scatter(x[selected]+360,y[selected],1,c=z[selected],alpha=0.5)
#plt.xlim(0,720)
#plt.ylim(-90,90)
plt.show()

# %%
plt.figure(figsize=(18,6))
plt.scatter(table.array['l'],table.array['b'],1,c=table.array['phot_g_mean_mag'],alpha=0.1)
plt.scatter(table.array['l']+360,table.array['b'],1,c=table.array['phot_g_mean_mag'],alpha=0.1)
plt.xlim(0,720)
plt.ylim(-90,90)
plt.colorbar()
plt.show()

# %%
plt.figure(figsize=(18,6))
plt.scatter(table.array['l'],table.array['b'],1,c=table.array['bp_rp'],alpha=0.1)
plt.scatter(table.array['l']+360,table.array['b'],1,c=table.array['bp_rp'],alpha=0.1)
plt.xlim(0,720)
plt.ylim(-90,90)
plt.colorbar()
plt.show()

# %%
plt.figure(figsize=(18,6))

x = table.array['l']
y = table.array['b']
z= table.array['phot_g_mean_mag']
selected = np.where((np.abs(bp_rp-0.5)<0.3) * (np.abs(g-15.5)<0.2))[0]

plt.scatter(x[selected],y[selected],1,c=z[selected],alpha=0.5)
plt.scatter(x[selected]+360,y[selected],1,c=z[selected],alpha=0.5)
plt.xlim(0,720)
plt.ylim(-90,90)
plt.show()
# Out:
# /home/scheng/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in less

# %%
plt.hist(table.array['parallax'],bins=100, range=(-2,2))
plt.show()
# Out:
# /home/scheng/miniconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:780: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/scheng/miniconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:781: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
plt.figure(figsize=(12,12))
selected = np.where(np.abs(table.array['b'])<35)[0]
x = table.array['phot_bp_mean_mag']-table.array['phot_rp_mean_mag']
y = table.array['phot_g_mean_mag']
plt.plot(x[selected],y[selected],'.',alpha=0.05)


selected = np.where(np.abs(table.array['b'])>35)[0]
x = table.array['phot_bp_mean_mag']-table.array['phot_rp_mean_mag']
y = table.array['phot_g_mean_mag']
plt.plot(x[selected],y[selected],'.',alpha=0.05)


plt.ylim(21,8)
plt.show()

# %%
plt.figure(figsize=(6,6))

selected = np.where((np.abs(b-78.7)<0.2) * (np.abs(l-42.1)<1))[0]
x = table.array['phot_bp_mean_mag']-table.array['phot_rp_mean_mag']
y = table.array['phot_g_mean_mag']
plt.plot(x[selected],y[selected],'.',alpha=1)

plt.ylim(21,8)
plt.show()

# %%
plt.figure(figsize=(12,12))
x = table.array['parallax']
y = table.array['phot_g_mean_mag']
plt.plot(x,y,'.',alpha=0.1)
plt.ylim(20,8)
plt.show()

# %%
x[selected]
print(x_median)
# Out:
# [2.06842501 1.49718667 0.8223419         nan        nan        nan
#         nan        nan        nan        nan]

# %%
n = 20
y_bin = np.linspace(8,20,n+1)
x = np.array(table.array['parallax'])
y = np.array(table.array['phot_g_mean_mag'])
x_median = np.zeros(n)
for i in range(n):
    selected = np.where((y > y_bin[i]) * (y < y_bin[i+1]) * (x>-100))[0]
    x_median[i] = np.median(x[selected])

plt.figure(figsize=(12,12))
plt.plot(x,y,'.',alpha=0.1)
plt.plot( x_median ,(y_bin[:-1]+y_bin[1:])/2, '.-')
plt.ylim(20,8)
plt.show()
# Out:
# /home/scheng/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in greater
#   import sys
# /home/scheng/miniconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/scheng/miniconda3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
plt.figure(figsize=(12,12))
plt.plot(y,x,'.',alpha=0.1)
plt.plot(  (y_bin[:-1]+y_bin[1:])/2, x_median, '.-')
plt.xlim(20,8)
plt.yscale('log')
plt.show()
# Out:
# /home/scheng/miniconda3/lib/python3.6/site-packages/matplotlib/scale.py:111: RuntimeWarning: invalid value encountered in less_equal
#   out[a <= 0] = -1000

# %%
Table.read(dir_rrlyrae+'main_statistics_rrlyrae.fits',format='fits')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/lib/python3.6/site-packages/astropy/utils/decorators.py in __get__(self, obj, owner)
#     705         try:
# --> 706             return obj.__dict__[self._key]
#     707         except KeyError:
#
# KeyError: 'data'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/lib/python3.6/site-packages/astropy/utils/decorators.py in __get__(self, obj, owner)
#     705         try:
# --> 706             return obj.__dict__[self._key]
#     707         except KeyError:
#
# KeyError: 'dtype'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-fd6623f32b80> in <module>()
# ...

# %%
data = hdul[0].data
data[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-d219bf0040d2> in <module>()
#       1 data = hdul[0].data
# ----> 2 data[1]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
Table.read('/datascope/menard/DATA/Gaia/gdr2/vari_time_series_statistics/csv/VariTimeSeriesStatistics_58.csv.gz',format='ascii')

# %%
SELECT source_id,ra,ra_error,dec,dec_error,parallax,parallax_error,phot_g_mean_mag,phot_bp_mean_mag,phot_rp_mean_mag,bp_rp,radial_velocity,radial_velocity_error,phot_variable_flag,teff_val,a_g_val FROM gaiadr2.gaia_source  
WHERE CONTAINS(POINT('ICRS',gaiadr2.gaia_source.ra,gaiadr2.gaia_source.dec),CIRCLE('ICRS',COORD1(EPOCH_PROP_POS(250.42347500000002,36.4613194,-246.6000,-1.7900,-7.0700,0,2000,2015.5)),COORD2(EPOCH_PROP_POS(250.42347500000002,36.4613194,-246.6000,-1.7900,-7.0700,0,2000,2015.5)),0.1))=1  
and pmra
